# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns

# %%
dados = pd.read_csv('../scrapped-content/cities_gdp.csv', sep=',')

# %%
dados.describe().round(2)
# Out:
#            year     city_id  state_id  agro_value_1000_brl  \
# count  55685.00    55685.00  55685.00             55685.00
# mean    2014.50  3253429.67     32.38             45431.24
# std        2.87   984714.21      9.83             81787.85
# min     2010.00  1100015.00     11.00                 0.00
# 25%     2012.00  2512101.00     25.00              8731.00
# 50%     2015.00  3146255.00     31.00             21816.00
# 75%     2017.00  4119152.00     41.00             49489.00
# max     2019.00  5300108.00     53.00           2482542.00
#
#        industry_value_1000_brl  services_value_1000_brl  \
# count                 55685.00             5.568500e+04
# mean                 207058.93             4.829187e+05
# std                 1333025.07             6.410927e+06
# min                      99.00             1.207000e+03
# 25%                    3221.00             1.488300e+04
# 50%                   10180.00             3.882600e+04
# 75%                   56445.00             1.246540e+05
# max                66893050.00             5.283801e+08
#
#        public_expending_value_1000_brl  total_value_1000_brl  \
# count                     5.568500e+04          5.568500e+04
# mean                      1.496661e+05          8.846421e+05
# std                       1.391605e+06          8.554081e+06
# min                       4.227000e+03          7.022000e+03
# 25%                       2.113700e+04          6.052000e+04
# 50%                       4.044700e+04          1.331550e+05
# 75%                       8.765500e+04          3.521430e+05
# max                       1.072192e+08          6.313280e+08
#
#        taxes_value_1000_brl  total_gdp_1000_brl  gdp_per_capita_brl
# count          5.568500e+04        5.568500e+04            55685.00
# mean           1.467619e+05        1.031363e+06            18961.03
# std            1.907779e+06        1.042699e+07            21034.77
# min            2.100000e+01        4.199000e+03              301.60
# 25%            2.437000e+03        6.326900e+04             7999.42
# 50%            7.359000e+03        1.410570e+05            13591.61
# 75%            2.820100e+04        3.816070e+05            23197.00
# max            1.324779e+08        7.638060e+08           815697.76

# %%
dados.head()
# Out:
#    year  city_id greater_region_name  state_id              city_name  \
# 0  2010  1100015               Norte        11  Alta Floresta D'Oeste
# 1  2010  1100023               Norte        11              Ariquemes
# 2  2010  1100031               Norte        11                 Cabixi
# 3  2010  1100049               Norte        11                 Cacoal
# 4  2010  1100056               Norte        11             Cerejeiras
#
#   metropolitan_region is_legal_amazon is_semi_arid is_sao_paulo_region  \
# 0                 NaN               t            f                   f
# 1                 NaN               t            f                   f
# 2                 NaN               t            f                   f
# 3                 NaN               t            f                   f
# 4                 NaN               t            f                   f
#
#    agro_value_1000_brl  industry_value_1000_brl  services_value_1000_brl  \
# 0              69260.0                  16119.0                  62496.0
# 1              73712.0                 287139.0                 494946.0
# 2              24301.0                   3253.0                  12677.0
# 3              95259.0                 182052.0                 465447.0
# 4              28976.0                  19734.0                  80725.0
#
#    public_expending_value_1000_brl  total_value_1000_brl  \
# 0                          93245.0              241120.0
# 1                         343868.0             1199664.0
# 2                          25170.0               65401.0
# 3                         298454.0             1041212.0
# 4                          63018.0              192454.0
#
#    taxes_value_1000_brl  total_gdp_1000_brl  gdp_per_capita_brl  \
# 0               20957.0            262077.0            10731.18
# 1              165030.0           1364694.0            15103.86
# 2                4210.0             69611.0            11033.62
# 3              145282.0           1186494.0            15095.15
# 4               29567.0            222021.0            13037.06
#
#                                most_valueable_sector
# 0  Administração, defesa, educação e saúde públic...
# 1  Administração, defesa, educação e saúde públic...
# 2  Administração, defesa, educação e saúde públic...
# 3  Administração, defesa, educação e saúde públic...
# 4  Administração, defesa, educação e saúde públic...

# %%
dados.corr().round(4)
# Out:
#                                    year  city_id  state_id  \
# year                             1.0000   0.0002    0.0002
# city_id                          0.0002   1.0000    0.9999
# state_id                         0.0002   0.9999    1.0000
# agro_value_1000_brl              0.1112   0.1842    0.1854
# industry_value_1000_brl          0.0165   0.0275    0.0271
# services_value_1000_brl          0.0163   0.0201    0.0197
# public_expending_value_1000_brl  0.0239   0.0208    0.0210
# total_value_1000_brl             0.0198   0.0245    0.0242
# taxes_value_1000_brl             0.0125   0.0199    0.0196
# total_gdp_1000_brl               0.0185   0.0238    0.0234
# gdp_per_capita_brl               0.1770   0.3140    0.3140
#
#                                  agro_value_1000_brl  industry_value_1000_brl  \
# year                                          0.1112                   0.0165
# city_id                                       0.1842                   0.0275
# state_id                                      0.1854                   0.0271
# agro_value_1000_brl                           1.0000                   0.0734
# industry_value_1000_brl                       0.0734                   1.0000
# services_value_1000_brl                       0.0448                   0.8162
# public_expending_value_1000_brl               0.1222                   0.5785
# total_value_1000_brl                          0.0744                   0.8623
# taxes_value_1000_brl                          0.0441                   0.8421
# total_gdp_1000_brl                            0.0691                   0.8615
# gdp_per_capita_brl                            0.2803                   0.2801
#
#                                  services_value_1000_brl  \
# year                                              0.0163
# city_id                                           0.0201
# state_id                                          0.0197
# agro_value_1000_brl                               0.0448
# industry_value_1000_brl                           0.8162
# services_value_1000_brl                           1.0000
# public_expending_value_1000_brl                   0.6819
# total_value_1000_brl                              0.9880
# taxes_value_1000_brl                              0.9752
# total_gdp_1000_brl                                0.9890
# gdp_per_capita_brl                                0.0964
#
#                                  public_expending_value_1000_brl  \
# year                                                      0.0239
# city_id                                                   0.0208
# state_id                                                  0.0210
# agro_value_1000_brl                                       0.1222
# industry_value_1000_brl                                   0.5785
# services_value_1000_brl                                   0.6819
# public_expending_value_1000_brl                           1.0000
# total_value_1000_brl                                      0.7651
# taxes_value_1000_brl                                      0.7081
# total_gdp_1000_brl                                        0.7572
# gdp_per_capita_brl                                        0.0825
#
#                                  total_value_1000_brl  taxes_value_1000_brl  \
# year                                           0.0198                0.0125
# city_id                                        0.0245                0.0199
# state_id                                       0.0242                0.0196
# agro_value_1000_brl                            0.0744                0.0441
# industry_value_1000_brl                        0.8623                0.8421
# services_value_1000_brl                        0.9880                0.9752
# public_expending_value_1000_brl                0.7651                0.7081
# total_value_1000_brl                           1.0000                0.9777
# taxes_value_1000_brl                           0.9777                1.0000
# total_gdp_1000_brl                             0.9993                0.9850
# gdp_per_capita_brl                             0.1319                0.1136
#
#                                  total_gdp_1000_brl  gdp_per_capita_brl
# year                                         0.0185              0.1770
# city_id                                      0.0238              0.3140
# state_id                                     0.0234              0.3140
# agro_value_1000_brl                          0.0691              0.2803
# industry_value_1000_brl                      0.8615              0.2801
# services_value_1000_brl                      0.9890              0.0964
# public_expending_value_1000_brl              0.7572              0.0825
# total_value_1000_brl                         0.9993              0.1319
# taxes_value_1000_brl                         0.9850              0.1136
# total_gdp_1000_brl                           1.0000              0.1290
# gdp_per_capita_brl                           0.1290              1.0000

# %%
ax = sns.boxplot(y='gdp_per_capita_brl', x='year', data=dados, orient='v', width=0.5)
ax.figure.set_size_inches(12, 6)
ax.set_title('Gdp per capita year', fontsize=20)
ax.set_ylabel('$$$', fontsize=16)
ax.set_xlabel('Year', fontsize=16)
ax
# Out:
# <AxesSubplot:title={'center':'Gdp per capita year'}, xlabel='Year', ylabel='$$$'>

# %%
ax = sns.distplot(dados['gdp_per_capita_brl'])
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências', fontsize=20)
ax.set_ylabel('Gdp per capita', fontsize=16)
ax
# Out:
# C:\Users\plini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Distribuição de Frequências'}, xlabel='gdp_per_capita_brl', ylabel='Gdp per capita'>

# %%
ax = sns.pairplot(dados, y_vars='gdp_per_capita_brl', x_vars=['is_legal_amazon', 'is_semi_arid', 'is_sao_paulo_region'])
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %%
import numpy as np
dados['log_gdp_per_capita'] = np.log(dados['gdp_per_capita_brl'])

# %%
ax = sns.distplot(dados['log_gdp_per_capita'])
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências Log', fontsize=20)
ax.set_ylabel('Gdp per capita', fontsize=16)
ax
# Out:
# C:\Users\plini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Distribuição de Frequências Log'}, xlabel='log_gdp_per_capita', ylabel='Gdp per capita'>

# %%
ax = sns.boxplot(y='log_gdp_per_capita', x='year', data=dados, orient='v', width=0.5)
ax.figure.set_size_inches(12, 6)
ax.set_title('Gdp per capita year log', fontsize=20)
ax.set_ylabel('$$$', fontsize=16)
ax.set_xlabel('Year', fontsize=16)
ax
# Out:
# <AxesSubplot:title={'center':'Gdp per capita year log'}, xlabel='Year', ylabel='$$$'>
